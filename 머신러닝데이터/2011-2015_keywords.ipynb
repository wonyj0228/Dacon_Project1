# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
import re

# %%
data = pd.read_excel("../newsdata/NewsResult_20110101-20151231.xlsx")

# %%
# 사용할 컬럼 추출
data = data[['일자','특성추출(가중치순 상위 50개)']]

# %%
data.dtypes
# Out:
# 일자                    int64
# 특성추출(가중치순 상위 50개)    object
# dtype: object

# %%
data['일자'] = data['일자'].astype(str)  #데이터타입 string으로 변경 (연도,월 까지 표기하기 위해)

# %%
date = []
for x in data['일자']:
    date.append(x[0:6])
data['일자'] = date

# %%
data.head()
# Out:
#        일자                                  특성추출(가중치순 상위 50개)
# 0  201512  가계부채,부동산,서울,수도권,주택대출,홈페이지,가계대출,한국은행,원리금,상승률,60...
# 1  201512  부동산,전세난,강남,신도시,가능성,상반기,고준석,부센터장,박합수,김규정,지점장,박상...
# 2  201512                           부동산,서울,강남,수도권,분양가,재건축,만큼
# 3  201512  상승세,서울,오름세,부동산,아파트담보대출금리비교,제주시,서귀포시,한국감정원,매매시세...
# 4  201512  상승세,서울,오름세,부동산,아파트담보대출금리비교,제주시,한경닷컴,서귀포시,한국감정원...

# %%
data.info() #null 값이 있는지 체크
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18980 entries, 0 to 18979
# Data columns (total 2 columns):
# 일자                   18980 non-null object
# 특성추출(가중치순 상위 50개)    18980 non-null object
# dtypes: object(2)
# memory usage: 296.6+ KB

# %%
# 일자별 키워드 합치기
data = data.groupby('일자').sum()
data
# Out:
#                                         특성추출(가중치순 상위 50개)
# 일자
# 201101  판교,판교역,대우건설,경기도,주상복합,월드마크,분당,임대료,성남시,고속도로,수도권,...
# 201102  분양가,한강,서울,계약금,올림픽대로,김포한강로,중과세,힐스테이트,투자가치,상승세,전...
# 201103  한강,서울,분양가,김포한강로,올림픽대로,자연앤힐스테이트,중도금,분양가상한제,강남,방...
# 201104  용인,강남,성복,서울,48채,성복지구,성복동,용인시,죽전역,수지구,전세금,판교,13...
# 201105  부동산,수도권,부동산시장,상승세,김선덕,연구소,이문기,한성대,김완중,김희선,미분양,...
# 201106  상승세,모기지증권,긴축안,인도분,뉴욕,미국,수수료,프랑스,연준,뉴욕증시,상한선,유럽...
# 201107  강남,부동산,자존심,전원마을,우면산,하락세,이호연,이영진,형촌마을,채훈식,관계자,중...
# 201108  전주,송천동,부동산,middot,한라비발디,전북,전세가,전주지역,한라건설,비발디,공...
# 201109  서산테크노밸리,서산시,예천,근린공원,주차장,분양가,우림필유,조합원,400여,경기장,...
# 201110  김수엽,조망권,일조권,부동산컨설팅,아이디명,마린보이,서정렬,서성수,동호회,광안리,부...
# 201111  부동산,판교,투자자,분양가,분양전환,사업자,지식산업센터,인천,통째,1실,유스페이스,...
# 201112  부동산,전문가,팀장,만큼,집마련,부사장,본부장,연구원,실수요자,상반기,장희순,박점희...
# 201201  용인,용인시,서울,수도권,분당선,경기도,공연장,계약금,신도시,전용면적,전셋값,전세가...
# 201202  미국,내구재,소비자,나스닥지수,주택가격,전문가,마이크론,항공기,1만,최고치,다우지수...
# 201203  500만,서울,1000만,하락세,저가매물,부동산,일산,내발산동,15주,매수세,과천,...
# 201204  강남,서울,강남권,급매물,부동산,상승세,강남구,가능성,송파구,개포,강남3구,주택시장...
# 201205  부동산,베이징,거래량,조정정책,베이징대,1만,최고치,연구원,조윤선,2000여건,단월...
# 201412  신년사,부총리,그간,활성화,노동시장,개방화,서승환,경직성,지역별,구조개혁,이동필,미...
# 201501  강동구,고덕,재건축,보증금,서울,상승률,관계자,암사동,4억,저금리,부동산,사람들,분...
# 201502  상승세,재건축,강동구,오름세,국민은행,이주수요,광역시,강북,강남,고덕주공,대구지하철...
# 201503  서울,울산,상승폭,광주광역시,제주,인천,상승세,세종시,대구,연립주택,한국감정원,아파...
# 201504  상승세,수도권,상승폭,봄철,한국감정원,전셋값,그간,광주,대구,하남시,오름세,실수요자...
# 201505  아파텔,전용면적,관계자,서울,분양가,기흥역,부천,전세난,임채우,경쟁률,부동산,4베이...
# 201506  전셋값,전세가격,정책처,한국주택금융공사,연구위원,전세지원,안정성,보증실적,전세가율,...
# 201507  건설사,분양가,청주,서희건설,조합원,서희스타힐스,공급가,지역주택조합아파트,가마지구,...
# 201508  서울,제주,수도권,강남,상승세,전세가격,대구,경북,행복도시,강북,상승폭,광주,가계부...
# 201509  전세난,서울,부동산,경기도,공인중개사,집주인,재개발,상승률,분양시장,500세대,건설...
# 201510  서울,죽전,샬레,죽전역,수도권,상반기,파인비스타,경부고속도로,보정동,거래량,풍덕천,...
# 201511  상승폭,서울,제주,준전세,시군구,관망세,전세가격,수요자,수도권,준월세,매매가,월세가...
# 201512  가계부채,부동산,서울,수도권,주택대출,홈페이지,가계대출,한국은행,원리금,상승률,60...

# %%
# 키워드 value를 한글만 남기고 모두 삭제
def text_cleaning(text):
    text = str(text)
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub(' ', text)
    return result

# %%
data['특성추출(가중치순 상위 50개)'] = data['특성추출(가중치순 상위 50개)'].apply(lambda x: text_cleaning(x))

# %%
from konlpy.tag import Okt
from collections import Counter

# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
data['상승'] = 0
data['하락']=0
for i in range (0,len(data['특성추출(가중치순 상위 50개)'])):
    nouns_tagger = Okt()
    nouns = nouns_tagger.nouns(data['특성추출(가중치순 상위 50개)'][i])
    count = Counter(nouns)
    count = dict(count)

    up_key_list = []
    down_key_list = []
    for x in count.keys():
        if '상승' in x:
            up_key_list.append(x)
        if '하락' in x:
            down_key_list.append(x)

    up_count = 0
    down_count = 0
    for x in up_key_list:
        up_count= up_count+ count.get(x)
    for x in down_key_list:    
        down_count= down_count+ count.get(x)
    data['상승'][i] = up_count
    data['하락'][i] = down_count

# %%
data
# Out:
#                                         특성추출(가중치순 상위 50개)   상승  하락
# 일자
# 201101  판교 판교역 대우건설 경기도 주상복합 월드마크 분당 임대료 성남시 고속도로 수도권 ...  171  19
# 201102  분양가 한강 서울 계약금 올림픽대로 김포한강로 중과세 힐스테이트 투자가치 상승세 전...  167   9
# 201103  한강 서울 분양가 김포한강로 올림픽대로 자연앤힐스테이트 중도금 분양가상한제 강남 방...   94  19
# 201104  용인 강남 성복 서울 채 성복지구 성복동 용인시 죽전역 수지구 전세금 판교 만 구 ...   66  27
# 201105  부동산 수도권 부동산시장 상승세 김선덕 연구소 이문기 한성대 김완중 김희선 미분양 ...   96  48
# 201106  상승세 모기지증권 긴축안 인도분 뉴욕 미국 수수료 프랑스 연준 뉴욕증시 상한선 유럽...  100  28
